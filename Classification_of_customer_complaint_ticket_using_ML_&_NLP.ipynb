# %%
import numpy as np
import pandas as pd
import json
import re
import string
import nltk
from nltk.corpus import stopwords
import spacy, string
import en_core_web_sm
nlp = en_core_web_sm.load()
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from nltk.tokenize import word_tokenize
from nltk import pos_tag
import seaborn as sns
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split,GridSearchCV

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
f = open('/content/drive/MyDrive/Scania/complaints-2021-05-14_08_16.json')

# %%
data = json.load(f)

# %%
data = pd.json_normalize(data)

# %%
data.head()
# Out:
#                 _index      _type      _id  _score   _source.tags  \
# 0  complaint-public-v2  complaint  3211475     0.0           None
# 1  complaint-public-v2  complaint  3229299     0.0  Servicemember
# 2  complaint-public-v2  complaint  3199379     0.0           None
# 3  complaint-public-v2  complaint  2673060     0.0           None
# 4  complaint-public-v2  complaint  3203545     0.0           None
#
#   _source.zip_code _source.complaint_id                       _source.issue  \
# 0            90301              3211475   Attempts to collect debt not owed
# 1            319XX              3229299     Written notification about debt
# 2            77069              3199379  Other features, terms, or problems
# 3            48066              2673060      Trouble during payment process
# 4            10473              3203545                    Fees or interest
#
#        _source.date_received _source.state  ... _source.company_response  \
# 0  2019-04-13T12:00:00-05:00            CA  ...  Closed with explanation
# 1  2019-05-01T12:00:00-05:00            GA  ...  Closed with explanation
# 2  2019-04-02T12:00:00-05:00            TX  ...  Closed with explanation
# 3  2017-09-13T12:00:00-05:00            MI  ...  Closed with explanation
# 4  2019-04-05T12:00:00-05:00            NY  ...  Closed with explanation
#
#         _source.company _source.submitted_via _source.date_sent_to_company  \
# 0  JPMORGAN CHASE & CO.                   Web    2019-04-13T12:00:00-05:00
# 1  JPMORGAN CHASE & CO.                   Web    2019-05-01T12:00:00-05:00
# 2  JPMORGAN CHASE & CO.                   Web    2019-04-02T12:00:00-05:00
# 3  JPMORGAN CHASE & CO.                   Web    2017-09-14T12:00:00-05:00
# 4  JPMORGAN CHASE & CO.              Referral    2019-04-05T12:00:00-05:00
#
#   _source.company_public_response                         _source.sub_product  \
# 0                            None                            Credit card debt
# 1                            None                            Credit card debt
# 2                            None  General-purpose credit card or charge card
# 3                            None                  Conventional home mortgage
# 4                            None  General-purpose credit card or charge card
#
#   _source.timely                    _source.complaint_what_happened  \
# 0            Yes
# 1            Yes  Good morning my name is XXXX XXXX and I apprec...
# 2            Yes  I upgraded my XXXX XXXX card in XX/XX/2018 and...
# 3            Yes
# 4            Yes
#
#                                   _source.sub_issue  \
# 0                                 Debt is not yours
# 1  Didn't receive enough information to verify debt
# 2             Problem with rewards from credit card
# 3                                              None
# 4                         Charged too much interest
#
#   _source.consumer_consent_provided
# 0              Consent not provided
# 1                  Consent provided
# 2                  Consent provided
# 3              Consent not provided
# 4                               N/A
#
# [5 rows x 22 columns]

# %%
data.columns
# Out:
# Index(['_index', '_type', '_id', '_score', '_source.tags', '_source.zip_code',
#        '_source.complaint_id', '_source.issue', '_source.date_received',
#        '_source.state', '_source.consumer_disputed', '_source.product',
#        '_source.company_response', '_source.company', '_source.submitted_via',
#        '_source.date_sent_to_company', '_source.company_public_response',
#        '_source.sub_product', '_source.timely',
#        '_source.complaint_what_happened', '_source.sub_issue',
#        '_source.consumer_consent_provided'],
#       dtype='object')

# %%
data = data[['_source.complaint_what_happened','_source.product','_source.sub_product']]

# %%
data.head()
# Out:
#                      _source.complaint_what_happened  \
# 0
# 1  Good morning my name is XXXX XXXX and I apprec...
# 2  I upgraded my XXXX XXXX card in XX/XX/2018 and...
# 3
# 4
#
#                _source.product                         _source.sub_product
# 0              Debt collection                            Credit card debt
# 1              Debt collection                            Credit card debt
# 2  Credit card or prepaid card  General-purpose credit card or charge card
# 3                     Mortgage                  Conventional home mortgage
# 4  Credit card or prepaid card  General-purpose credit card or charge card

# %%
data = data.rename(columns={'_source.complaint_what_happened' : 'complaint_text', '_source.product' : 'category', '_source.sub_product' : 'sub_category'})

# %%
data.head()
# Out:
#                                       complaint_text  \
# 0
# 1  Good morning my name is XXXX XXXX and I apprec...
# 2  I upgraded my XXXX XXXX card in XX/XX/2018 and...
# 3
# 4
#
#                       category                                sub_category
# 0              Debt collection                            Credit card debt
# 1              Debt collection                            Credit card debt
# 2  Credit card or prepaid card  General-purpose credit card or charge card
# 3                     Mortgage                  Conventional home mortgage
# 4  Credit card or prepaid card  General-purpose credit card or charge card

# %%
data['category'] = data['category'] + ' + ' + data['sub_category']
data = data.drop(['sub_category'],axis = 1)
data.head()
# Out:
#                                       complaint_text  \
# 0
# 1  Good morning my name is XXXX XXXX and I apprec...
# 2  I upgraded my XXXX XXXX card in XX/XX/2018 and...
# 3
# 4
#
#                                             category
# 0                 Debt collection + Credit card debt
# 1                 Debt collection + Credit card debt
# 2  Credit card or prepaid card + General-purpose ...
# 3              Mortgage + Conventional home mortgage
# 4  Credit card or prepaid card + General-purpose ...

# %%
data.complaint_text.isnull().sum()
# Out:
# 0

# %%
len(data[data['complaint_text'] ==""])
# Out:
# 57241

# %%
data[data['complaint_text']==""] = np.nan
data.complaint_text.isnull().sum()
# Out:
# 57241

# %%
data = data[~data['complaint_text'].isnull()]
data.complaint_text.isnull().sum()
# Out:
# 0

# %%
# data.dropna(axis= 0, subset=['complaint_text'],inplace = True)

# %%
data.complaint_text.isnull().sum()
# Out:
# 0

# %%
def remove(text):
    text = text.lower()
    text = re.sub('\[.*\]','', text).strip()
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = re.sub('\S*\d\S*\s*','', text).strip()
    return text.strip()

# %%
data.complaint_text = data.complaint_text.apply(lambda x : remove(x))
data.complaint_text.head()
# Out:
# 1     good morning my name is xxxx xxxx and i apprec...
# 2     i upgraded my xxxx xxxx card in and was told b...
# 10    chase card was reported on however fraudulent ...
# 11    on while trying to book a xxxx  xxxx  ticket i...
# 14    my grand son give me check for i deposit it in...
# Name: complaint_text, dtype: object

# %%
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

nltk.download('punkt')
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
def lemmatize(x):
  text = word_tokenize(x)
  words = [word for word in text if word not in stop_words]
  lemma_words = [lemmatizer.lemmatize(word, pos = wordnet.VERB) for word in words]
  return ' '.join(lemma_words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
data['lemma'] = data.complaint_text.apply(lambda x : lemmatize(x))

# %%
data.head()
# Out:
#                                        complaint_text  \
# 1   good morning my name is xxxx xxxx and i apprec...
# 2   i upgraded my xxxx xxxx card in and was told b...
# 10  chase card was reported on however fraudulent ...
# 11  on while trying to book a xxxx  xxxx  ticket i...
# 14  my grand son give me check for i deposit it in...
#
#                                              category  \
# 1                  Debt collection + Credit card debt
# 2   Credit card or prepaid card + General-purpose ...
# 10  Credit reporting, credit repair services, or o...
# 11  Credit reporting, credit repair services, or o...
# 14     Checking or savings account + Checking account
#
#                                                 lemma
# 1   good morning name xxxx xxxx appreciate could h...
# 2   upgrade xxxx xxxx card tell agent upgrade anni...
# 10  chase card report however fraudulent applicati...
# 11  try book xxxx xxxx ticket come across offer ap...
# 14  grand son give check deposit chase account fun...

# %%
data_clean = data[['complaint_text','lemma','category']]
data_clean.head()
# Out:
#                                        complaint_text  \
# 1   good morning my name is xxxx xxxx and i apprec...
# 2   i upgraded my xxxx xxxx card in and was told b...
# 10  chase card was reported on however fraudulent ...
# 11  on while trying to book a xxxx  xxxx  ticket i...
# 14  my grand son give me check for i deposit it in...
#
#                                                 lemma  \
# 1   good morning name xxxx xxxx appreciate could h...
# 2   upgrade xxxx xxxx card tell agent upgrade anni...
# 10  chase card report however fraudulent applicati...
# 11  try book xxxx xxxx ticket come across offer ap...
# 14  grand son give check deposit chase account fun...
#
#                                              category
# 1                  Debt collection + Credit card debt
# 2   Credit card or prepaid card + General-purpose ...
# 10  Credit reporting, credit repair services, or o...
# 11  Credit reporting, credit repair services, or o...
# 14     Checking or savings account + Checking account

# %%
data.shape
# Out:
# (21072, 3)

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

def extract_nouns(text):
    words = word_tokenize(text)
    pos_tags = pos_tag(words)
    nouns = [word for word, pos in pos_tags if pos == 'NN']
    return ' '.join(nouns)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
data_clean['complaint_pos_removed'] = data_clean['lemma'].apply(lambda x : extract_nouns(x))
data_clean.head()
# Out:
# <ipython-input-128-ce5dc89140a5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_clean['complaint_pos_removed'] = data_clean['lemma'].apply(lambda x : extract_nouns(x))
#                                        complaint_text  \
# 1   good morning my name is xxxx xxxx and i apprec...
# 2   i upgraded my xxxx xxxx card in and was told b...
# 10  chase card was reported on however fraudulent ...
# 11  on while trying to book a xxxx  xxxx  ticket i...
# 14  my grand son give me check for i deposit it in...
#
#                                                 lemma  \
# 1   good morning name xxxx xxxx appreciate could h...
# 2   upgrade xxxx xxxx card tell agent upgrade anni...
# 10  chase card report however fraudulent applicati...
# 11  try book xxxx xxxx ticket come across offer ap...
# 14  grand son give check deposit chase account fun...
#
#                                              category  \
# 1                  Debt collection + Credit card debt
# 2   Credit card or prepaid card + General-purpose ...
# 10  Credit reporting, credit repair services, or o...
# 11  Credit reporting, credit repair services, or o...
# 14     Checking or savings account + Checking account
#
#                                 complaint_pos_removed
# 1   morning name appreciate chase bank cardmember ...
# 2   card tell agent date information order upgrade...
# 10  card report application submit identity consen...
# 11  book ticket come offer apply ticket card infor...
# 14  son check deposit chase account fund bank acco...

# %%
fig = plt.figure(figsize=(10,10))
text_lens = [len(s) for s in data_clean.complaint_pos_removed]
plt.hist(text_lens, bins = 50)
# Out:
# (array([8.005e+03, 6.492e+03, 3.094e+03, 1.477e+03, 9.090e+02, 4.800e+02,
#         2.170e+02, 1.130e+02, 6.300e+01, 5.100e+01, 4.000e+01, 2.400e+01,
#         1.500e+01, 2.100e+01, 1.300e+01, 8.000e+00, 1.000e+01, 3.000e+00,
#         6.000e+00, 2.000e+00, 2.000e+00, 2.000e+00, 7.000e+00, 1.000e+00,
#         3.000e+00, 0.000e+00, 0.000e+00, 4.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 2.000e+00, 1.000e+00,
#         0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         1.000e+00, 1.000e+00]),
#  array([    0.  ,   220.56,   441.12,   661.68,   882.24,  1102.8 ,
#          1323.36,  1543.92,  1764.48,  1985.04,  2205.6 ,  2426.16,
#          2646.72,  2867.28,  3087.84,  3308.4 ,  3528.96,  3749.52,
#          3970.08,  4190.64,  4411.2 ,  4631.76,  4852.32,  5072.88,
#          5293.44,  5514.  ,  5734.56,  5955.12,  6175.68,  6396.24,
#          6616.8 ,  6837.36,  7057.92,  7278.48,  7499.04,  7719.6 ,
#          7940.16,  8160.72,  8381.28,  8601.84,  8822.4 ,  9042.96,
#          9263.52,  9484.08,  9704.64,  9925.2 , 10145.76, 10366.32,
#         10586.88, 10807.44, 11028.  ]),
#  <BarContainer object of 50 artists>)

# %%
from wordcloud import WordCloud
fig = plt.figure(figsize=(10,10))
wordcloud = WordCloud(stopwords = stop_words, max_words = 40).generate(str(data_clean.complaint_pos_removed))
print(wordcloud)
plt.imshow(wordcloud)
plt.show()
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x79d25776ab30>

# %%
data_clean['complaint_clean'] = data_clean['complaint_pos_removed'].str.replace('-PRON-','')
data_clean = data_clean.drop(['complaint_pos_removed'],axis=1)
# Out:
# <ipython-input-131-939aa139c9c8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_clean['complaint_clean'] = data_clean['complaint_pos_removed'].str.replace('-PRON-','')

# %%
data_clean.head()
# Out:
#                                        complaint_text  \
# 1   good morning my name is xxxx xxxx and i apprec...
# 2   i upgraded my xxxx xxxx card in and was told b...
# 10  chase card was reported on however fraudulent ...
# 11  on while trying to book a xxxx  xxxx  ticket i...
# 14  my grand son give me check for i deposit it in...
#
#                                                 lemma  \
# 1   good morning name xxxx xxxx appreciate could h...
# 2   upgrade xxxx xxxx card tell agent upgrade anni...
# 10  chase card report however fraudulent applicati...
# 11  try book xxxx xxxx ticket come across offer ap...
# 14  grand son give check deposit chase account fun...
#
#                                              category  \
# 1                  Debt collection + Credit card debt
# 2   Credit card or prepaid card + General-purpose ...
# 10  Credit reporting, credit repair services, or o...
# 11  Credit reporting, credit repair services, or o...
# 14     Checking or savings account + Checking account
#
#                                       complaint_clean
# 1   morning name appreciate chase bank cardmember ...
# 2   card tell agent date information order upgrade...
# 10  card report application submit identity consen...
# 11  book ticket come offer apply ticket card infor...
# 14  son check deposit chase account fund bank acco...

# %%
def get_top_n_bigram(text, ngram=1, top=None):
    vec = CountVectorizer(ngram_range=(ngram, ngram), stop_words='english').fit(text)
    bag_of_words = vec.transform(text)

    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]

    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:top]

# %%
top_30_unigrams = get_top_n_bigram(data_clean.complaint_clean,ngram=1, top=30)
top_30_bigrams = get_top_n_bigram(data_clean.complaint_clean,ngram=2, top=30)
top_30_trigrams = get_top_n_bigram(data_clean.complaint_clean,ngram=3, top=30)

# %%
top_30_unigrams[:10]
# Out:
# [('chase', 51779),
#  ('account', 42460),
#  ('credit', 34156),
#  ('bank', 30027),
#  ('card', 26221),
#  ('charge', 16817),
#  ('time', 16097),
#  ('payment', 13946),
#  ('xxxx', 13215),
#  ('check', 12887)]

# %%
df1 = pd.DataFrame(top_30_unigrams, columns = ['unigram' , 'count'])
plt.figure(figsize=(12,6))
fig = sns.barplot(x=df1['unigram'], y=df1['count'])
plt.xticks(rotation = 80)
plt.show()

# %%
top_30_bigrams[:10]
# Out:
# [('credit card', 12616),
#  ('chase bank', 5327),
#  ('credit report', 5035),
#  ('check account', 4092),
#  ('customer service', 3066),
#  ('chase credit', 2978),
#  ('bank account', 2673),
#  ('account chase', 2305),
#  ('chase account', 2010),
#  ('account account', 1905)]

# %%
df2 = pd.DataFrame(top_30_bigrams, columns = ['bigram' , 'count'])
plt.figure(figsize=(12,6))
fig = sns.barplot(x=df2['bigram'], y=df2['count'])
plt.xticks(rotation = 80)
plt.show()

# %%
top_30_trigrams[:10]
# Out:
# [('chase credit card', 2086),
#  ('credit card company', 1006),
#  ('credit card account', 914),
#  ('credit card chase', 738),
#  ('credit card credit', 572),
#  ('charge credit card', 491),
#  ('chase customer service', 490),
#  ('credit report credit', 472),
#  ('report credit report', 451),
#  ('chase check account', 423)]

# %%
df3 = pd.DataFrame(top_30_trigrams, columns = ['trigram' , 'count'])
plt.figure(figsize=(12,6))
fig = sns.barplot(x=df3['trigram'], y=df3['count'])
plt.xticks(rotation = 80)
plt.show()

# %%
data_clean.head()
# Out:
#                                        complaint_text  \
# 1   good morning my name is xxxx xxxx and i apprec...
# 2   i upgraded my xxxx xxxx card in and was told b...
# 10  chase card was reported on however fraudulent ...
# 11  on while trying to book a xxxx  xxxx  ticket i...
# 14  my grand son give me check for i deposit it in...
#
#                                                 lemma  \
# 1   good morning name xxxx xxxx appreciate could h...
# 2   upgrade xxxx xxxx card tell agent upgrade anni...
# 10  chase card report however fraudulent applicati...
# 11  try book xxxx xxxx ticket come across offer ap...
# 14  grand son give check deposit chase account fun...
#
#                                              category  \
# 1                  Debt collection + Credit card debt
# 2   Credit card or prepaid card + General-purpose ...
# 10  Credit reporting, credit repair services, or o...
# 11  Credit reporting, credit repair services, or o...
# 14     Checking or savings account + Checking account
#
#                                       complaint_clean
# 1   morning name appreciate chase bank cardmember ...
# 2   card tell agent date information order upgrade...
# 10  card report application submit identity consen...
# 11  book ticket come offer apply ticket card infor...
# 14  son check deposit chase account fund bank acco...

# %%
data_clean['complaint_clean'] = data_clean['complaint_clean'].str.replace('xxxx','')

# %%
data_clean.head()
# Out:
#                                        complaint_text  \
# 1   good morning my name is xxxx xxxx and i apprec...
# 2   i upgraded my xxxx xxxx card in and was told b...
# 10  chase card was reported on however fraudulent ...
# 11  on while trying to book a xxxx  xxxx  ticket i...
# 14  my grand son give me check for i deposit it in...
#
#                                                 lemma  \
# 1   good morning name xxxx xxxx appreciate could h...
# 2   upgrade xxxx xxxx card tell agent upgrade anni...
# 10  chase card report however fraudulent applicati...
# 11  try book xxxx xxxx ticket come across offer ap...
# 14  grand son give check deposit chase account fun...
#
#                                              category  \
# 1                  Debt collection + Credit card debt
# 2   Credit card or prepaid card + General-purpose ...
# 10  Credit reporting, credit repair services, or o...
# 11  Credit reporting, credit repair services, or o...
# 14     Checking or savings account + Checking account
#
#                                       complaint_clean
# 1   morning name appreciate chase bank cardmember ...
# 2   card tell agent date information order upgrade...
# 10  card report application submit identity consen...
# 11  book ticket come offer apply ticket card infor...
# 14  son check deposit chase account fund bank acco...

# %%
tfidf = TfidfVectorizer(min_df = 2, max_df = 0.95, stop_words = 'english')

# %%
dtm = tfidf.fit_transform(data_clean.complaint_clean)

# %%
tfidf.get_feature_names_out()[:10]
# Out:
# array(['aarp', 'aback', 'abandon', 'abandonment', 'abatement',
#        'abbreviation', 'abd', 'abet', 'abhorrent', 'abide'], dtype=object)

# %%
len(tfidf.get_feature_names_out())
# Out:
# 6745

# %%
from sklearn.decomposition import NMF

# %%
num_topics =  5

nmf_model = NMF(n_components=num_topics, random_state=40)

W1 = nmf_model.fit_transform(dtm)
H1 = nmf_model.components_

# %%
num_words=15

vocab = np.array(tfidf.get_feature_names_out())

top_words = lambda t: [vocab[i] for i in np.argsort(t)[:-num_words-1:-1]]
topic_words = ([top_words(t) for t in H1])
topics = [' '.join(t) for t in topic_words]

# %%
vocab
# Out:
# array(['aarp', 'aback', 'abandon', ..., 'zombie', 'zone', 'zoom'],
#       dtype=object)

# %%
topics
# Out:
# ['account bank check money chase deposit fund branch tell number transfer claim business fraud cash',
#  'credit report card chase inquiry account company score information debt limit letter application use bureaus',
#  'loan mortgage home chase modification property letter time house refinance bank rate document foreclosure sale',
#  'charge card chase fee dispute purchase merchant fraud claim transaction refund service time company pay',
#  'payment balance pay fee month statement auto date time account chase day transfer car post']

# %%
colnames = ["Topic" + str(i) for i in range(nmf_model.n_components)]
docnames = ["Doc" + str(i) for i in range(len(data_clean.complaint_clean))]
df_doc_topic = pd.DataFrame(np.round(W1, 2), columns=colnames, index=docnames)
significant_topic = np.argmax(df_doc_topic.values, axis=1)
df_doc_topic['dominant_topic'] = significant_topic
df_doc_topic.head()
# Out:
#       Topic0  Topic1  Topic2  Topic3  Topic4  dominant_topic
# Doc0    0.03    0.01    0.02    0.01    0.01               0
# Doc1    0.01    0.01    0.01    0.01    0.00               0
# Doc2    0.00    0.06    0.00    0.00    0.00               1
# Doc3    0.02    0.06    0.02    0.01    0.00               1
# Doc4    0.08    0.00    0.00    0.00    0.00               0

# %%
data_clean['Topic'] = significant_topic

# %%
data_clean.head()
# Out:
#                                        complaint_text  \
# 1   good morning my name is xxxx xxxx and i apprec...
# 2   i upgraded my xxxx xxxx card in and was told b...
# 10  chase card was reported on however fraudulent ...
# 11  on while trying to book a xxxx  xxxx  ticket i...
# 14  my grand son give me check for i deposit it in...
#
#                                                 lemma  \
# 1   good morning name xxxx xxxx appreciate could h...
# 2   upgrade xxxx xxxx card tell agent upgrade anni...
# 10  chase card report however fraudulent applicati...
# 11  try book xxxx xxxx ticket come across offer ap...
# 14  grand son give check deposit chase account fun...
#
#                                              category  \
# 1                  Debt collection + Credit card debt
# 2   Credit card or prepaid card + General-purpose ...
# 10  Credit reporting, credit repair services, or o...
# 11  Credit reporting, credit repair services, or o...
# 14     Checking or savings account + Checking account
#
#                                       complaint_clean  Topic
# 1   morning name appreciate chase bank cardmember ...      0
# 2   card tell agent date information order upgrade...      0
# 10  card report application submit identity consen...      1
# 11  book ticket come offer apply ticket card infor...      1
# 14  son check deposit chase account fund bank acco...      0

# %%
data_clean['Topic'].isnull().sum()
# Out:
# 0

# %%
temp = data_clean[['complaint_text','complaint_clean','category','Topic']].groupby('Topic').head(10)
temp.sort_values('Topic')
# Out:
#                                         complaint_text  \
# 1    good morning my name is xxxx xxxx and i apprec...
# 2    i upgraded my xxxx xxxx card in and was told b...
# 14   my grand son give me check for i deposit it in...
# 17   with out notice jp morgan chase restricted my ...
# 48   jp morgan chase bank please answer the followi...
# 43   chase sent me an email today with the innocuou...
# 24   mishandling of this account by chase auto and ...
# 42   my card went missing and i didnt realize it un...
# 27   i opened an account with chase bank on xxxx an...
# 35   i opened the saving account for the bonus i wa...
# 83   unknown inquire reported on my credit bureau s...
# 65   i opened the chasexxxx xxxx rewards credit car...
# 64   chase is marketing credit cards to those of us...
# 50   i am a senior citizen that has been scammed by...
# 59   i currently have over xxxx chase ultimate rewa...
# 10   chase card was reported on however fraudulent ...
# 26   i have reached out to xxxx several times in at...
# 23   i have a chase credit card which is incorrectl...
# 11   on while trying to book a xxxx  xxxx  ticket i...
# 15                       can you please remove inquiry
# 81   i bought a new xxxx xxxx on xxxxxxxx from xxxx...
# 99   my name is xxxx xxxx i have missed a payment i...
# 73   i have wired through one of chase branches in ...
# 127  i am xxxx military member  xxxx  with the xxxx...
# 156  chase issued a mortgage loan against my proper...
# 57   i have been trying to do a loan modification w...
# 203  jp morgan and chase reported loans   xxxx  xxx...
# 213  my mortgage is with chase my payments were bei...
# 265  i am submitting a complaint regarding the acti...
# 293  i ask chase auto finance please honor the writ...
# 101  i purchase is an airline ticket on xxxxxxxx an...
# 93   on we purchased a service with xxxx xxxx xxxx ...
# 88   i preordered an item on xxxxxxxx and paid with...
# 30   to whom it may concern chase bank charged wron...
# 78   my dispute is for not receiving services liste...
# 63   i tried to send almost at xxxx and the transac...
# 21   on xxxx i made a payment to an online retailer...
# 45   i made a purchase with xxxx xxxx xxxx on in th...
# 40   xxxx xxxx a sofa love seat table and chairs an...
# 32   my chase amazon card was declined for a cateri...
# 82   i recently called to ask chase bank why they r...
# 317  ive been actively trying to resolve this conce...
# 58   i made a purchase of on xxxxxxxx i made paymen...
# 164  in xxxx of this year chase withdrew money from...
# 167  a double payment from my chase debt cart to ch...
# 20   during the summer months i experience a declin...
# 287  i have a chase sapphire reserved card and the ...
# 294  spoke to the with payment arrangement xxxxxxxx...
# 296  claim number xxxx this complaint is in regard ...
# 339  on i purchased a used truck at xxxx at the tim...
#
#                                        complaint_clean  \
# 1    morning name appreciate chase bank cardmember ...
# 2    card tell agent date information order upgrade...
# 14   son check deposit chase account fund bank acco...
# 17   jp restrict account debit card tuesday thursda...
# 48   jp bank please question access information rea...
# 43   send email today title information regard chan...
# 24                                       account auto
# 42   card didnt realize today deposit money bank ac...
# 27   account bank  use code bonus call term tell ev...
# 35   save account bonus bonus auto transfer check t...
# 83     inquire report credit bureau  date company auto
# 65   chase reward credit card time reward point com...
# 64   chase market credit card credit style market c...
# 50   citizen company pay time share company nothing...
# 59   reward point try access reward account chase f...
# 10   card report application submit identity consen...
# 26   reach time inquiry tell contact creditor place...
# 23       chase credit card credit report company issue
# 11   book ticket come offer apply ticket card infor...
# 15                                             inquiry
# 81   pay loan release time resolution time release ...
# 99   name payment time loan modification loss mitig...
# 73   wire chase branch reinstatement amount bank or...
# 127  member auto finance refuse pay gap insurancewa...
# 156  issue mortgage loan property home insurance co...
# 57         try loan modification chase runaround im mo
# 203  jp report loan debt irs behalf address report ...
# 213  mortgage chase month provider chase transfer f...
# 265  submit complaint regard action chase home fore...
# 293  ask auto finance please agreement refund amoun...
# 101  purchase airline ticket dollar airport call ti...
# 93   purchase service group base dispute plan conve...
# 88   item pay chase credit card merchant estimate p...
# 30   concern bank charge fee alert balance fee bala...
# 78   dispute service list night hotel transportatio...
# 63   send transaction charge service refund card ac...
# 21   payment online retailer use pay chase website ...
# 45   purchase amount charge transaction place dispu...
# 40   sofa love seat chair charge bank claim furnitu...
# 32   chase decline cater order place amount contact...
# 82   ask bank report credit bureau payment call sho...
# 317  concern bank time report credit report fault c...
# 58   purchase payment date  please statement statem...
# 164  year chase money escrow property tax money pay...
# 167  payment chase debt cart credit card post wont ...
# 20   summer experience income employment month paym...
# 287  chase sapphire reserve card payment month pay ...
# 294  payment arrangement day number state today pay...
# 296  claim number complaint regard charge account t...
# 339  purchase use truck time purchase payment date ...
#
#                                               category  Topic
# 1                   Debt collection + Credit card debt      0
# 2    Credit card or prepaid card + General-purpose ...      0
# 14      Checking or savings account + Checking account      0
# 17      Checking or savings account + Checking account      0
# 48      Checking or savings account + Checking account      0
# 43   Credit card or prepaid card + General-purpose ...      0
# 24                        Vehicle loan or lease + Loan      0
# 42      Checking or savings account + Checking account      0
# 27      Checking or savings account + Checking account      0
# 35       Checking or savings account + Savings account      0
# 83   Credit reporting, credit repair services, or o...      1
# 65   Credit card or prepaid card + General-purpose ...      1
# 64   Credit card or prepaid card + General-purpose ...      1
# 50   Credit card or prepaid card + General-purpose ...      1
# 59   Credit card or prepaid card + General-purpose ...      1
# 10   Credit reporting, credit repair services, or o...      1
# 26   Credit reporting, credit repair services, or o...      1
# 23   Credit card or prepaid card + General-purpose ...      1
# 11   Credit reporting, credit repair services, or o...      1
# 15   Credit reporting, credit repair services, or o...      1
# 81                        Vehicle loan or lease + Loan      2
# 99               Mortgage + Conventional home mortgage      2
# 73   Mortgage + Home equity loan or line of credit ...      2
# 127                       Consumer Loan + Vehicle loan      2
# 156                            Mortgage + FHA mortgage      2
# 57               Mortgage + Conventional home mortgage      2
# 203                Student loan + Private student loan      2
# 213                             Mortgage + VA mortgage      2
# 265                  Mortgage + Other type of mortgage      2
# 293                      Vehicle loan or lease + Lease      2
# 101     Checking or savings account + Checking account      3
# 93   Credit card or prepaid card + General-purpose ...      3
# 88   Credit card or prepaid card + General-purpose ...      3
# 30      Checking or savings account + Checking account      3
# 78   Credit card or prepaid card + General-purpose ...      3
# 63      Checking or savings account + Checking account      3
# 21   Money transfer, virtual currency, or money ser...      3
# 45      Checking or savings account + Checking account      3
# 40      Checking or savings account + Checking account      3
# 32   Credit card or prepaid card + General-purpose ...      3
# 82                  Debt collection + Credit card debt      4
# 317                      Vehicle loan or lease + Lease      4
# 58   Credit card or prepaid card + General-purpose ...      4
# 164              Mortgage + Conventional home mortgage      4
# 167     Checking or savings account + Checking account      4
# 20                        Vehicle loan or lease + Loan      4
# 287  Credit card or prepaid card + General-purpose ...      4
# 294                 Debt collection + Credit card debt      4
# 296     Checking or savings account + Checking account      4
# 339                       Vehicle loan or lease + Loan      4

# %%
topic_mapping = {
    0: 'Bank Account services',
    1: 'Credit card or prepaid card',
    2: 'Others',
    3: 'Theft/Dispute Reporting',
    4: 'Mortgage/Loan'
}

data_clean['Topic'] = data_clean['Topic'].map(topic_mapping)

# %%
data_clean
# Out:
#                                           complaint_text  \
# 1      good morning my name is xxxx xxxx and i apprec...
# 2      i upgraded my xxxx xxxx card in and was told b...
# 10     chase card was reported on however fraudulent ...
# 11     on while trying to book a xxxx  xxxx  ticket i...
# 14     my grand son give me check for i deposit it in...
# ...                                                  ...
# 78303  after being a chase card customer for well ove...
# 78309  on wednesday xxxxxxxx i called chas my xxxx xx...
# 78310  i am not familiar with xxxx pay and did not un...
# 78311  i have had flawless credit for yrs ive had cha...
# 78312  roughly years ago i closed out my accounts wit...
#
#                                                    lemma  \
# 1      good morning name xxxx xxxx appreciate could h...
# 2      upgrade xxxx xxxx card tell agent upgrade anni...
# 10     chase card report however fraudulent applicati...
# 11     try book xxxx xxxx ticket come across offer ap...
# 14     grand son give check deposit chase account fun...
# ...                                                  ...
# 78303  chase card customer well decade offer multiple...
# 78309  wednesday xxxxxxxx call chas xxxx xxxx visa cr...
# 78310  familiar xxxx pay understand great risk provid...
# 78311  flawless credit yrs ive chase credit card chas...
# 78312  roughly years ago close account jp morgan chas...
#
#                                                 category  \
# 1                     Debt collection + Credit card debt
# 2      Credit card or prepaid card + General-purpose ...
# 10     Credit reporting, credit repair services, or o...
# 11     Credit reporting, credit repair services, or o...
# 14        Checking or savings account + Checking account
# ...                                                  ...
# 78303  Credit card or prepaid card + General-purpose ...
# 78309  Credit card or prepaid card + General-purpose ...
# 78310     Checking or savings account + Checking account
# 78311  Credit card or prepaid card + General-purpose ...
# 78312                                                NaN
#
#                                          complaint_clean  \
# 1      morning name appreciate chase bank cardmember ...
# 2      card tell agent date information order upgrade...
# 10     card report application submit identity consen...
# 11     book ticket come offer apply ticket card infor...
# 14     son check deposit chase account fund bank acco...
# ...                                                  ...
# 78303  chase card customer decade offer credit card c...
# 78309  call chas  credit card provider claim purchase...
# 78310  pay risk chase bank bank tell deal merchant me...
# 78311  flawless credit chase credit card chase freedo...
# 78312  bank order line credit pay account payment acc...
#
#                              Topic
# 1            Bank Account services
# 2            Bank Account services
# 10     Credit card or prepaid card
# 11     Credit card or prepaid card
# 14           Bank Account services
# ...                            ...
# 78303  Credit card or prepaid card
# 78309      Theft/Dispute Reporting
# 78310        Bank Account services
# 78311                Mortgage/Loan
# 78312                Mortgage/Loan
#
# [21072 rows x 5 columns]

# %%
data_clean['Topic'].isnull().any()
# Out:
# False

# %%
fig = plt.figure(figsize = (20,10))
sns.countplot(x='Topic', data = data_clean)
# Out:
# <Axes: xlabel='Topic', ylabel='count'>

# %%
data_clean['Topic'].unique()
# Out:
# array(['Bank Account services', 'Credit card or prepaid card',
#        'Mortgage/Loan', 'Theft/Dispute Reporting', 'Others'], dtype=object)

# %%
training_data = data_clean[['complaint_text','Topic']]

# %%
training_data.head()
# Out:
#                                        complaint_text  \
# 1   good morning my name is xxxx xxxx and i apprec...
# 2   i upgraded my xxxx xxxx card in and was told b...
# 10  chase card was reported on however fraudulent ...
# 11  on while trying to book a xxxx  xxxx  ticket i...
# 14  my grand son give me check for i deposit it in...
#
#                           Topic
# 1         Bank Account services
# 2         Bank Account services
# 10  Credit card or prepaid card
# 11  Credit card or prepaid card
# 14        Bank Account services

# %%
# reverse_topic_mapping = {
#     'Bank Account services' :0,
#     'Credit card or prepaid card':1,
#     'Others':2,
#     'Theft/Dispute Reporting':3,
#     'Mortgage/Loan':4

# }

# training_data['Topic'] = training_data['Topic'].map(reverse_topic_mapping)
# training_data.head()
training = training_data.copy()
topic_reverse = []
topic = np.array(training['Topic'])
for i in range(len(topic)):
  if(topic[i] == 'Bank Account services'):
    topic_reverse.append(0)
  if(topic[i] == 'Credit card or prepaid card'):
    topic_reverse.append(1)
  if(topic[i] == 'Others'):
    topic_reverse.append(2)
  if(topic[i] == 'Theft/Dispute Reporting'):
    topic_reverse.append(3)
  if(topic[i] == 'Mortgage/Loan'):
    topic_reverse.append(4)

training.drop(['Topic'],axis = 1, inplace = True)
training['Topic'] = topic_reverse

# %%
len(topic)
# Out:
# 21072

# %%
len(topic_reverse)
# Out:
# 21072

# %%
training['Topic']
# Out:
# 1        0
# 2        0
# 10       1
# 11       1
# 14       0
#         ..
# 78303    1
# 78309    3
# 78310    0
# 78311    4
# 78312    4
# Name: Topic, Length: 21072, dtype: int64

# %%
training['Topic'].isnull().sum()
# Out:
# 0

# %%
training[['complaint_text','Topic']][training.Topic == 2].head(30)
# Out:
#                                         complaint_text  Topic
# 57   i have been trying to do a loan modification w...      2
# 73   i have wired through one of chase branches in ...      2
# 81   i bought a new xxxx xxxx on xxxxxxxx from xxxx...      2
# 99   my name is xxxx xxxx i have missed a payment i...      2
# 127  i am xxxx military member  xxxx  with the xxxx...      2
# 156  chase issued a mortgage loan against my proper...      2
# 203  jp morgan and chase reported loans   xxxx  xxx...      2
# 213  my mortgage is with chase my payments were bei...      2
# 265  i am submitting a complaint regarding the acti...      2
# 293  i ask chase auto finance please honor the writ...      2
# 316  re  complaint against jp morgan chase xxxx hom...      2
# 333  i have applied for a chase credit card i am al...      2
# 353  my information was used to obtain a loan from ...      2
# 382  i want to raise concern due the company not re...      2
# 386  i am responding to your contact about a debt y...      2
# 402  i applied for a chase credit card affiliated w...      2
# 413  in regards to xxxx  chase card services  can s...      2
# 434  on i went into a chase branch to close a check...      2
# 446  on i filed a complaint with cfpb against chase...      2
# 458  i have a small xxxx xxxx xxxx  xxxx xxxx xxxx ...      2
# 521  i have been a customer with chase bank for alm...      2
# 538  i am requesting a onetime day courtesy foreclo...      2
# 584  xxxx xxxx xxxx on has an inquiries that i did ...      2
# 593  i have been looking for a home to purchase sin...      2
# 628  i am a real estate attorney in massachusetts j...      2
# 650  on xxxxxxxx i obtained a home equity line of c...      2
# 668  jpmorgan chase and company may have attempted ...      2
# 678  i have been overpaying my loan to pay down the...      2
# 683  this is not a duplicate complaint this is a ne...      2
# 726  i paid off my mortgage in through chase it was...      2

# %%
x = training.complaint_text
y = training.Topic

# %%
y.isnull().sum()
# Out:
# 0

# %%
x.isnull().sum()
# Out:
# 0

# %%
y.shape
# Out:
# (21072,)

# %%
# y.fillna(y.median(),inplace = True)

# %%
y.isnull().sum()
# Out:
# 0

# %%
count_vect = CountVectorizer()
x_vect = count_vect.fit_transform(x)

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer()
x_tfidf = tfidf_transformer.fit_transform(x_vect)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_tfidf, y, test_size = 0.25, random_state = 40, stratify = y)

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
mnb = MultinomialNB()
mnb.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
metric1 = []
y_pred = mnb.predict(x_test)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# %%
model_report_test = classification_report(y_test,y_pred)
print('Classification Report for Test:\n',model_report_test)
# Out:
# Classification Report for Test:
#                precision    recall  f1-score   support
#
#            0       0.54      0.95      0.69      1525
#            1       0.69      0.74      0.71      1310
#            2       0.92      0.64      0.75       937
#            3       0.89      0.47      0.62      1047
#            4       0.00      0.00      0.00       449
#
#     accuracy                           0.66      5268
#    macro avg       0.61      0.56      0.55      5268
# weighted avg       0.67      0.66      0.63      5268
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
class_labels = training['Topic'].unique()

# %%
class_labels
# Out:
# array([0, 1, 4, 3, 2])

# %%
# fig = plt.subplots(figsize=(12, 8))
# cm = confusion_matrix(y_test, y_pred)
# cmp = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = class_labels)
# cmp.plot(cmap = plt.cm.Blues)
# plt.xticks(rotation=80)
# plt.show()

# %%
lr_model = LogisticRegression(random_state = 40, solver = 'liblinear')
lr_model.fit(x_train,y_train)
# Out:
# LogisticRegression(random_state=40, solver='liblinear')

# %%
y_pred = lr_model.predict(x_test)
model_report = classification_report(y_test,y_pred)
print("Classification report :\n", model_report)
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92      1525
#            1       0.91      0.92      0.92      1310
#            2       0.95      0.92      0.93       937
#            3       0.90      0.91      0.90      1047
#            4       0.94      0.78      0.85       449
#
#     accuracy                           0.91      5268
#    macro avg       0.92      0.89      0.91      5268
# weighted avg       0.91      0.91      0.91      5268

# %%
dtc = DecisionTreeClassifier(random_state = 40)
dtc.fit(x_train,y_train)
y_pred = dtc.predict(x_test)
model_report = classification_report(y_test,y_pred)
print("Classification report :\n",model_report )
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79      1525
#            1       0.80      0.81      0.80      1310
#            2       0.83      0.82      0.83       937
#            3       0.71      0.72      0.72      1047
#            4       0.71      0.70      0.71       449
#
#     accuracy                           0.78      5268
#    macro avg       0.77      0.77      0.77      5268
# weighted avg       0.78      0.78      0.78      5268

# %%
rf = RandomForestClassifier(n_estimators = 500, random_state = 40, n_jobs = -1, oob_score = True)
rf.fit(x_train,y_train)

print('OOB SCORE : ', rf.oob_score_)
y_pred = rf.predict(x_test)
model_report = classification_report(y_test,y_pred)
print("Classification report:\n", model_report)
# Out:
# OOB SCORE :  0.8153631991900785
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.94      0.85      1525
#            1       0.81      0.87      0.84      1310
#            2       0.89      0.86      0.87       937
#            3       0.86      0.80      0.83      1047
#            4       0.96      0.28      0.43       449
#
#     accuracy                           0.82      5268
#    macro avg       0.86      0.75      0.76      5268
# weighted avg       0.84      0.82      0.81      5268

# %%
folds = KFold(n_splits = 5, shuffle = True, random_state = 40)

# %%
def gridSearch(model,folds, params,scoring):
  grid_search = GridSearchCV(model,
                             cv = folds,
                             param_grid = params,
                             scoring = scoring,
                             n_jobs = -1,
                             verbose = 1)
  return grid_search

# %%
def print_best_params(model):
  print("Best Score : ", model.best_score_)
  print("Best Hyperparameter :", model.best_params_)

# %%
mnb = MultinomialNB()
mnb_params = {'alpha' : (1, 0.1, 0.01, 0.001, 0.0001)}
grid_search_mnb = gridSearch(mnb, folds, mnb_params, scoring = None)
grid_search_mnb.fit(x_train, y_train)
print_best_params(grid_search_mnb)
y_pred = grid_search_mnb.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# Best Score :  0.765819561186774
# Best Hyperparameter : {'alpha': 0.01}
#               precision    recall  f1-score   support
#
#            0       0.76      0.85      0.80      1525
#            1       0.73      0.75      0.74      1310
#            2       0.84      0.84      0.84       937
#            3       0.77      0.72      0.75      1047
#            4       0.62      0.43      0.50       449
#
#     accuracy                           0.76      5268
#    macro avg       0.74      0.72      0.73      5268
# weighted avg       0.76      0.76      0.76      5268

# %%
lr_model = LogisticRegression()
lr_params = {'C' : [0.01, 1, 10],
             'penalty' : ['l1','l2'],
             'solver' : ['liblinear','newton-cg','saga']}
grid_search_lr =  gridSearch(lr_model,folds,lr_params,scoring=None)
grid_search_lr.fit(x_train,y_train)
print_best_params(grid_search_lr)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 15 fits failed out of a total of 90.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.54150818        nan 0.57061497 0.60902326 0.66002303 0.66008628
#  0.92723387        nan 0.93096709 0.9080616  0.91407242 0.91407244
#  0.91514815        nan 0.93077719 0.91306012 0.9143254  0.91457851]
#   warnings.warn(
# Best Score :  0.9309670870057944
# Best Hyperparameter : {'C': 1, 'penalty': 'l1', 'solver': 'saga'}

# %%
y_pred = grid_search_lr.predict(x_test)
print('Classification report :\n', classification_report(y_test,y_pred))
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95      1525
#            1       0.95      0.93      0.94      1310
#            2       0.95      0.94      0.95       937
#            3       0.92      0.94      0.93      1047
#            4       0.93      0.90      0.92       449
#
#     accuracy                           0.94      5268
#    macro avg       0.94      0.93      0.94      5268
# weighted avg       0.94      0.94      0.94      5268

# %%
dtc = DecisionTreeClassifier(random_state = 40)
dtc_params = {
    'max_depth' : [5,10,20,30],
    'min_samples_leaf' : [5,10,20,30]
}

grid_search_dtc = gridSearch(dtc,folds,dtc_params,scoring=None)
grid_search_dtc.fit(x_train,y_train)
print_best_params(grid_search_dtc)
y_pred = grid_search_dtc.predict(x_test)
print('Classification report :\n', classification_report(y_test, y_pred))
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# Best Score :  0.7937231648372771
# Best Hyperparameter : {'max_depth': 20, 'min_samples_leaf': 20}
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.79      0.81      0.80      1525
#            1       0.81      0.84      0.82      1310
#            2       0.82      0.85      0.83       937
#            3       0.79      0.74      0.77      1047
#            4       0.84      0.72      0.78       449
#
#     accuracy                           0.80      5268
#    macro avg       0.81      0.79      0.80      5268
# weighted avg       0.80      0.80      0.80      5268

# %%
# rfc = RandomForestClassifier(random_state = 40, n_jobs = -1, oob_score = True)
# rfc_params = {'max_depth' : [10,20,30,40],
#               'min_samples_leaf' : [5,10,15,20,30],
#               'n_estimators' : [100,200,500,700]}
# grid_search_rfc = gridSearch(rfc,folds,rfc_params,scoring = None)
# grid_search_rfc.fit(x_train,y_train)
# print('OOB Score:', grid_search_rfc.best_estimator_.oob_score_)
# print_best_params(grid_search_rfc)
# y_pred = grid_search_rfc.predict(x_test)
# print("Classification report\n" : classification_report(y_test,y_pred))

# %%
test_complaint= 'I tried to make a transaction at a supermarket retail store, using my chase \
debit/atm card, but the transaction was declined. I am still able to withdraw money out of an \
ATM machine using the same debit card. Please resolve this issue.'

# %%
test = count_vect.transform([test_complaint])
test_tfidf = tfidf_transformer.transform(test)
prediction = grid_search_lr.predict(test_tfidf)
prediction
# Out:
# array([3])

# %%
topic_mapping[prediction[0]]
# Out:
# 'Theft/Dispute Reporting'
